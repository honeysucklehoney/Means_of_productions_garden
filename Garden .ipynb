# %%
garden= open('garden template.txt').read()

# %%
import random

# %%
print(garden)
# Out:
#
#      [s&p
#     willow]
#   ii  		 aa bb aa bb aa		||eee eee eee gg gg ii gg ||  [cherry tree]
#     		 cc aa cc aa cc		||ff ff ee eee eee hh hh  ||
#   ii  		 aa bb dd bb aa		||ff ff gg eee eee hh hh  ||
#     		 aa aa aa aa aa
#   ii  		 aa cc aa cc aa	  	  aa   aa   bb   bb   cc
#     								cc   aa   aa   kk    	[shed]
#   ii                                 aa   cc   dd   aa        nn
#   ii
#                       jj        jj  jj    jj   	       uu
# 				jj      jj  jj jj  jj
# 				lll lll lll mmm eee mmm mmm lll mmm lll ww          nn
# 		           i   lll   lll	lll  mmm  lll  mmm
#
# ii---ii-	 -ii ----- ii ------ ii ----- ii ------ ii ---- ii ----ii	nn  uu         vv nn
#                 [paloma]
#  [paloma]
#
# ii --- ii---	-- ii ----- ii ------ ii ----- ii ------ ii ---- ii ---- nn      ii	ww
#                 nn	 nn	     nn           nn     nn nn       		                uu
#
# ii	ii	ii  	ii    ii	ii  	ii     ii    ii 	ii		          nn   xx  +[nettle]+
# ...

# %%
map_bit= garden.split('\t')
#print(map_bit)
#map = '✱'.join(map_bit)
#print(map)
map_bit
# Out:
# ['  \n     [s&p \n    willow] \n  ii  ',
#  '',
#  ' aa bb aa bb aa',
#  '',
#  '||eee eee eee gg gg ii gg ||  [cherry tree]',
#  '\n    ',
#  '',
#  ' cc aa cc aa cc',
#  '',
#  '||ff ff ee eee eee hh hh  ||',
#  '',
#  '\n  ii  ',
#  '',
#  ' aa bb dd bb aa',
#  '',
#  '||ff ff gg eee eee hh hh  ||',
#  '  ',
#  '    \n    ',
#  '',
#  ' aa aa aa aa aa       \n  ii  ',
#  '',
#  ' aa cc aa cc aa',
#  '  ',
#  '  aa   aa   bb   bb   cc  ',
#  '\n    ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'cc   aa   aa   kk    ',
#  '[shed]\n  ii                                 aa   cc   dd   aa        nn\n  ii                                             \n                      jj        jj  jj    jj   ',
#  '       uu\n',
#  '',
#  '',
#  '',
#  'jj      jj  jj jj  jj\n',
#  '',
#  '',
#  '',
#  'lll lll lll mmm eee mmm mmm lll mmm lll ww          nn\n',
#  '',
#  '           i   lll   lll',
#  'lll  mmm  lll  mmm \n                     \nii---ii-',
# ...

# %%
fibre_plants= ['Day_lily',
              'Iris',
              'yucca',
            'milkweed',
              'phorium tanax',
               'golden hops',
              ]

# %%
dye_plants= ['tea bush',
            'elderberry',
            'marigold',
            'lupine',
            'pokeberry',
            'madder root',
            'coreopsis',
            'hollyhocks',
            'st johns wort',
            'japanese indigo',
            'dyers knotweed',
            'woad',
            'blood root',
            'mahonia',
            'pansy',
            'boradge',
            'yellow dock']

# %%
fibre_trees= ['black willow',
                'bamboo',
             'yellow willow',
              'elderberry'
             ]

# %%
trees= ['hazel',
       'cherry',
       'paloma',
        'ash']

# %%
blackberry = "✹blackberry✿"

# %%
food_plants_south= ['common plantain'
'tanzi',
'sunchocke',
'creeping buttercup',
'cumfrey',
'elecampane',
'yellow dock',
'stinging nettle',
'mustard green',
'rosehip',
'goutweed',
'mock orange',
'organ grape'

             ]

# %%
food_plants_north= [
                   'blackberry',
                   'rasberry',
                   'blueberry',
                   'thimble berry',
                    'snow berry'
                   ]

# %%
fruit_trees= ['snow apple',
             'cherry',
             'plum',
             'liberty apple']

# %%
bottom_plants = ['tansy',
              'fireweed',
              'lupine',
              'furny stuff']

# %%
import random

#for space in map_bit:
    #if  space.startswith(' a'):
        #random_plant_a = random.choice(fibre_plants)
        #random_plant_a_ready4print = " " + random_plant_a + " "
        #map_bit.append(random_plant_a_ready4print)
        
a_words = garden.replace( 'aa', ' ' + random.choice(fibre_plants) + ' ')
b_words = a_words.replace('bb', ' ' + random.choice(fibre_plants) + ' ')
c_words = b_words.replace('cc', ' ' + random.choice(dye_plants) + ' ')
d_words = c_words.replace('dd', ' ' + random.choice(fibre_plants) + ' ')

e_words = d_words.replace('eee', ' ' + random.choice(dye_plants) + ' ')
f_words = e_words.replace('ff', ' ' + random.choice(dye_plants) + ' ')
g_words = f_words.replace('gg', ' ' + random.choice(dye_plants) + ' ')
h_words = g_words.replace('hh', ' ' + random.choice(dye_plants) + ' ')

i_words = h_words.replace('ii', ' ' + random.choice(trees) + ' ')
j_words = i_words.replace('jj', ' ' + random.choice(fibre_trees) + ' ')

k_words = j_words.replace('kk', ' ' + random.choice(fibre_plants) + ' ')

l_words = k_words.replace ('lll', ' ' + random.choice(fibre_trees) + ' ')
m_words = l_words.replace ('mmm', ' ' + random.choice(fibre_trees) + ' ')
n_words = m_words.replace ('nn',' ' + random.choice(food_plants_south) + ' ' )
o_words = n_words.replace ('ooo',' ' + random.choice(food_plants_north) + ' ' )

p_words = o_words.replace ('pp',' ' + random.choice(fruit_trees) + ' ' )
q_words = p_words.replace ('qq',' ' + random.choice(fruit_trees) + ' ' )
r_words = q_words.replace ('rrr',' ' + random.choice(bottom_plants) + ' ' )
s_words = r_words.replace ('ss',' ' + random.choice(bottom_plants) + ' ' )

u_words = s_words.replace ('uu',' ' + random.choice(food_plants_south) + ' ' )
v_words = u_words.replace ('vv',' ' + random.choice(food_plants_south) + ' ' )
w_words = v_words.replace ('ww',' ' + random.choice(food_plants_south) + ' ' )
x_words = w_words.replace ('xx',' ' + random.choice(food_plants_south) + ' ' )

y_words = x_words.replace ('yy',' ' + random.choice(food_plants_north) + ' ' )
z_words = y_words.replace ('zz',' ' + random.choice(food_plants_north) + ' ' )
one_words = z_words.replace ('1',' ' + random.choice(trees) + ' ' )
two_words = one_words.replace ('2',' ' + random.choice(trees) + ' ' )
three_words = two_words.replace ('3',' ' + random.choice(trees) + ' ' )






print(three_words)
# Out:
#
#      [s&p
#     willow]
#    paloma   		  Iris   phorium tanax   Iris   phorium tanax   Iris 		|| dyers knotweed   dyers knotweed   dyers knotweed   st johns wort   st johns wort   paloma   st johns wort  ||  [cherry tree]
#     		  ma milkweed er root   Iris   ma milkweed er root   Iris   ma milkweed er root 		|| hollyhocks   hollyhocks  ee  dyers knotweed   dyers knotweed   boradge   boradge   ||
#    paloma   		  Iris   phorium tanax   milkweed   phorium tanax   Iris 		|| hollyhocks   hollyhocks   st johns wort   dyers knotweed   dyers knotweed   boradge   boradge   ||
#     		  Iris   Iris   Iris   Iris   Iris
#    paloma   		  Iris   ma milkweed er root   Iris   ma milkweed er root   Iris 	  	   Iris     Iris     phorium tanax     phorium tanax     ma milkweed er root
#     								 ma milkweed er root     Iris     Iris     Day_lily     	[shed]
#    paloma                                   Iris     ma milkweed er root     milkweed     Iris          organ grape
#    paloma
# ...

# %%
garden_new = open("garden_new")

# %%
garden_new.append(x_words)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-436-d4fb598fd25e> in <module>
# ----> 1 garden_new.append(x_words)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'append'

# %%
conda install -c conda-forge markovify
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - markovify
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |   py37hc8dfbb8_1         3.0 MB  conda-forge
#     markovify-0.8.0            |             py_0          11 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     unidecode-1.1.1            |             py_0         157 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
import markovify

# Get raw text as string.
with open("dreams.txt") as f:
    text = f.read()

text_model = markovify.NewlineText(text)
    
# Print five randomly-generated sentences
for i in range(5):
    sentence = text_model.make_sentence()
print(sentence)
# Out:
# None
